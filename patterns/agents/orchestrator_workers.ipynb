# %% [markdown]
# # Orchestrator-Workers Workflow
#
# ## Introduction
#
# Have you ever needed multiple perspectives on the same task, but couldn't predict in advance which perspectives would be most valuable? The orchestrator-workers pattern solves this by having a central LLM analyze each unique task and dynamically determine the best subtasks to delegate to specialized worker LLMs.
#
# Traditional approaches either require manual prompting multiple times or use hardcoded parallelization that generates the same variations regardless of context.
#
# With this approach, an orchestrator LLM analyzes the task, determines which variations would be most valuable for this specific case, then delegates to worker LLMs that generate each variation.
#
# ### What You'll Build
#
# A system that takes a product description request and:
#
# 1. Analyzes what types of marketing copy would be valuable
# 2. Dynamically generates specialized task descriptions for workers
# 3. Produces multiple content variations optimized for different audiences
# 4. Returns coordinated results from all workers
#
# ### Prerequisites
#
# - Python 3.9 or higher
# - Anthropic API key set as environment variable: `export ANTHROPIC_API_KEY='your-key'`
# - Basic understanding of prompt engineering
# - Familiarity with Python classes and type hints
#
#
# ### When to use this workflow
#
# This workflow is well-suited for complex tasks where you can't predict the subtasks needed in advance. The key difference from simple parallelization is its flexibility—subtasks aren't pre-defined, but determined by the orchestrator based on the specific input.
#
# **Use this pattern when:**
#
# - Tasks require multiple distinct approaches or perspectives
# - The optimal subtasks depend on the specific input
# - You need to compare different strategies or styles
#
# **Don't use this pattern when:**
#
# - You have simple, single-output tasks (unnecessary complexity)
# - Latency is critical (multiple LLM calls add overhead)
# - Subtasks are predictable and can be pre-defined (use simpler parallelization)
#
# ## How It Works
#
# The orchestrator-workers pattern operates in two phases:
#
# 1. **Analysis & Planning Phase**: The orchestrator LLM receives the task and context, analyzes what approaches would be valuable, and generates structured subtask descriptions in XML format.
#
# 2. **Execution Phase**: Each worker LLM receives:
#    - The original task for context
#    - Its specific subtask type and description
#    - Any additional context provided
#
# The orchestrator decides *at runtime* what subtasks to create, making this more adaptive than pre-defined parallel workflows.

# %% [markdown]
# ## Setup
#
# ### Installation
# ```bash
# pip install anthropic
# ```
#
# ### Helper Functions
# This example uses helper functions from `util.py` for making LLM calls and parsing XML responses:
#
# - `llm_call(prompt, system_prompt="", model="claude-sonnet-4-6")`: Sends a prompt to Claude and returns the text response
# - `extract_xml(text, tag)`: Extracts content from XML tags using regex
#
# These utilities handle API authentication (reading `ANTHROPIC_API_KEY` from environment) and provide a simple interface for the orchestrator-workers pattern. You can view the complete implementation in [util.py](util.py).
#
# ## Implementation
#
# The `FlexibleOrchestrator` class coordinates the two-phase workflow:
#
# **Key design decisions:**
# - Prompts are templates that accept runtime variables (`task`, `context`) for flexibility
# - XML is used for structured output parsing (reliable and language-model-friendly format)
# - Workers receive both the original task AND their specific instructions for better context
# - Error handling validates that workers return non-empty responses
#
# The implementation includes:
# - `parse_tasks()`: Parses the orchestrator's XML output into structured task dictionaries
# - `FlexibleOrchestrator.process()`: Main coordination logic that calls orchestrator, then workers
# - Response validation to catch and handle empty worker outputs

# %%
# !wget -q https://raw.githubusercontent.com/anthropics/anthropic-cookbook/main/patterns/agents/util.py
# !pip install anthropic -q

import os
from google.colab import userdata
os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.6/753.6 kB 11.1 MB/s eta 0:00:00

# %%
from util import extract_xml, llm_call

# Model configuration
MODEL = "claude-sonnet-4-6"  # Fast, capable model for both orchestrator and workers


def parse_tasks(tasks_xml: str) -> list[dict]:
    """Parse XML tasks into a list of task dictionaries."""
    tasks = []
    current_task = {}

    for line in tasks_xml.split("\n"):
        line = line.strip()
        if not line:
            continue

        if line.startswith("<task>"):
            current_task = {}
        elif line.startswith("<type>"):
            current_task["type"] = line[6:-7].strip()
        elif line.startswith("<description>"):
            current_task["description"] = line[12:-13].strip()
        elif line.startswith("</task>"):
            if "description" in current_task:
                if "type" not in current_task:
                    current_task["type"] = "default"
                tasks.append(current_task)

    return tasks


class FlexibleOrchestrator:
    """Break down tasks and run them in parallel using worker LLMs."""

    def __init__(
        self,
        orchestrator_prompt: str,
        worker_prompt: str,
        model: str = MODEL,
    ):
        """Initialize with prompt templates and model selection."""
        self.orchestrator_prompt = orchestrator_prompt
        self.worker_prompt = worker_prompt
        self.model = model

    def _format_prompt(self, template: str, **kwargs) -> str:
        """Format a prompt template with variables."""
        try:
            return template.format(**kwargs)
        except KeyError as e:
            raise ValueError(f"Missing required prompt variable: {e}") from e

    def process(self, task: str, context: dict | None = None) -> dict:
        """Process task by breaking it down and running subtasks in parallel."""
        context = context or {}

        # Step 1: Get orchestrator response
        orchestrator_input = self._format_prompt(self.orchestrator_prompt, task=task, **context)
        orchestrator_response = llm_call(orchestrator_input, model=self.model)

        # Parse orchestrator response
        analysis = extract_xml(orchestrator_response, "analysis")
        tasks_xml = extract_xml(orchestrator_response, "tasks")
        tasks = parse_tasks(tasks_xml)

        print("\n" + "=" * 80)
        print("ORCHESTRATOR ANALYSIS")
        print("=" * 80)
        print(f"\n{analysis}\n")

        print("\n" + "=" * 80)
        print(f"IDENTIFIED {len(tasks)} APPROACHES")
        print("=" * 80)
        for i, task_info in enumerate(tasks, 1):
            print(f"\n{i}. {task_info['type'].upper()}")
            print(f"   {task_info['description']}")

        print("\n" + "=" * 80)
        print("GENERATING CONTENT")
        print("=" * 80 + "\n")

        # Step 2: Process each task
        worker_results = []
        for i, task_info in enumerate(tasks, 1):
            print(f"[{i}/{len(tasks)}] Processing: {task_info['type']}...")

            worker_input = self._format_prompt(
                self.worker_prompt,
                original_task=task,
                task_type=task_info["type"],
                task_description=task_info["description"],
                **context,
            )

            worker_response = llm_call(worker_input, model=self.model)
            worker_content = extract_xml(worker_response, "response")

            # Validate worker response - handle empty outputs
            if not worker_content or not worker_content.strip():
                print(f"⚠️  Warning: Worker '{task_info['type']}' returned no content")
                worker_content = f"[Error: Worker '{task_info['type']}' failed to generate content]"

            worker_results.append(
                {
                    "type": task_info["type"],
                    "description": task_info["description"],
                    "result": worker_content,
                }
            )

        # Display results
        print("\n" + "=" * 80)
        print("RESULTS")
        print("=" * 80)
        for i, result in enumerate(worker_results, 1):
            print(f"\n{'-' * 80}")
            print(f"Approach {i}: {result['type'].upper()}")
            print(f"{'-' * 80}")
            print(f"\n{result['result']}\n")

        return {
            "analysis": analysis,
            "worker_results": worker_results,
        }

# %% [markdown]
# ## Example Use Case: Marketing Variation Generation
#
# Now let's see the orchestrator-workers pattern in action with a practical example: generating multiple styles of marketing copy for a product.
#
# **Why this example demonstrates the pattern well:**
# - Different products benefit from different marketing angles
# - The "best" variations depend on the specific product features and target audience
# - The orchestrator can adapt its strategy based on the input rather than using a fixed template
#
# **Prompt design notes:**
# - The orchestrator prompt asks for 2-3 approaches and provides XML structure guidance
# - The worker prompt gives workers full context (original task, their style, and guidelines)
# - Both prompts use clear XML formatting to ensure reliable parsing

# %%
ORCHESTRATOR_PROMPT = """
Analyze this task and break it down into 2-3 distinct approaches:

Task: {task}

Return your response in this format:

<analysis>
Explain your understanding of the task and which variations would be valuable.
Focus on how each approach serves different aspects of the task.
</analysis>

<tasks>
    <task>
    <type>formal</type>
    <description>Write a precise, technical version that emphasizes specifications</description>
    </task>
    <task>
    <type>conversational</type>
    <description>Write an engaging, friendly version that connects with readers</description>
    </task>
</tasks>
"""

WORKER_PROMPT = """
Generate content based on:
Task: {original_task}
Style: {task_type}
Guidelines: {task_description}

Return your response in this format:

<response>
Your content here, maintaining the specified style and fully addressing requirements.
</response>
"""


orchestrator = FlexibleOrchestrator(
    orchestrator_prompt=ORCHESTRATOR_PROMPT,
    worker_prompt=WORKER_PROMPT,
)

results = orchestrator.process(
    task="Write a product description for a new eco-friendly water bottle",
    context={
        "target_audience": "environmentally conscious millennials",
        "key_features": ["plastic-free", "insulated", "lifetime warranty"],
    },
)
# Out:
# ================================================================================
# ORCHESTRATOR ANALYSIS
# ================================================================================
#
#
# The task requires creating a product description for an eco-friendly water bottle. This type of copywriting can serve multiple audiences and purposes, so breaking it into distinct approaches adds real value. A formal approach would appeal to retailers, B2B buyers, or technically-minded consumers who want specifications and certifications. A conversational approach would connect emotionally with everyday consumers browsing online stores. A third approach focused on sustainability storytelling could target environmentally-conscious buyers who are motivated by impact and values rather than specs or personality alone. Each version serves a different channel (catalog, e-commerce, social/campaign) and a different buyer psychology.
#
#
#
# ================================================================================
# IDENTIFIED 3 APPROACHES
# ================================================================================
#
# 1. FORMAL
#    >Write a precise, technical product description that highlights material specifications (e.g., BPA-free, recycled materials percentage), certifications (e.g., FDA-approved, B Corp), capacity, insulation performance, and durability metrics. Suited for retail catalogs or B2B procurement contexts.<
#
# 2. CONVERSATIONAL
#    >Write a warm, engaging description that speaks directly to the everyday consumer. Use friendly, relatable language to highlight how the bottle fits into their lifestyle, keeps drinks fresh, and makes them feel good about their purchase. Ideal for e-commerce product pages or social media.<
#
# 3. STORYTELLING/MISSION-DRIVEN
#    >Write a values-forward description that frames the bottle as part of a larger environmental movement. Emphasize impact metrics (e.g., plastic bottles saved, carbon footprint reduced), brand mission, and the buyer's role as a conscious changemaker. Best suited for campaign landing pages or eco-focused marketplaces.<
#
# ================================================================================
# GENERATING CONTENT
# ================================================================================
#
# [1/3] Processing: formal...
# [2/3] Processing: conversational...
# [3/3] Processing: storytelling/mission-driven...
#
# ================================================================================
# RESULTS
# ================================================================================
#
# --------------------------------------------------------------------------------
# Approach 1: FORMAL
# --------------------------------------------------------------------------------
#
#
#
# **EcoVessel Pro 750 | Sustainable Insulated Water Bottle**
#
# **Product Overview**
#
# The EcoVessel Pro 750 is a premium, environmentally responsible hydration solution engineered for performance-driven consumers and institutional procurement applications. Constructed from 94% post-consumer recycled stainless steel (Grade 18/8, AISI 304), this vessel delivers exceptional thermal retention while significantly reducing reliance on virgin raw materials. The product is fully compliant with applicable environmental and safety standards, making it suitable for corporate wellness programs, hospitality procurement, and retail distribution.
#
# ---
#
# **Material Specifications**
#
# - **Body Construction:** 94% post-consumer recycled 18/8 stainless steel (food-grade AISI 304); 6% virgin alloy reinforcement for structural integrity
# - **Exterior Coating:** Water-based, solvent-free powder coat finish; zero volatile organic compound (VOC) formulation
# - **Lid & Seal Components:** BPA-free, BPS-free, and phthalate-free Tritan™ copolyester; food-grade silicone gasket seal
# - **Insulation Technology:** Dual-wall vacuum insulation with copper-plated inner chamber; nitrogen-purged cavity to minimize thermal conductivity
#
# ---
#
# **Certifications & Compliance**
#
# - FDA-approved materials (21 CFR 177.1520 compliant)
# - California Proposition 65 compliant
# - B Corp Certified manufacturer
# - ISO 14001:2015 Environmental Management System certified
# - NSF/ANSI Standard 51 certified (food equipment materials)
# - REACH and RoHS compliant (EU markets)
#
# ---
#
# **Performance Metrics**
#
# | Parameter | Specification |
# |---|---|
# | Capacity | 750 mL (25.4 fl oz) |
# | Cold Retention | ≥ 24 hours at ambient 25°C (77°F) |
# | Hot Retention | ≥ 12 hours at ambient 25°C (77°F) |
# | Operating Temperature Range | -20°C to 100°C (-4°F to 212°F) |
# | Leak-Proof Rating | IP67 (submersion tested to 1 m / 30 min) |
#
# ---
#
# **Durability & Structural Metrics**
#
# - **Drop Resistance:** Tested to withstand repeated impact from 1.5 m (4.9 ft) onto concrete substrate without structural failure or seal compromise
# - **Cycle Durability:** Lid mechanism rated for ≥ 10,000 open/close cycles
# - **Corrosion Resistance:** Salt spray tested per ASTM B117 (500-hour exposure; no measurable degradation)
# - **Wall Thickness:** 0.8 mm (body); 1.2 mm (base reinforcement)
# - **Weight:** 285 g (10.1 oz) empty
#
# ---
#
# **Sustainability Profile**
#
# - Carbon footprint: 1.8 kg CO₂e per unit (third-party verified, cradle-to-gate)
# - Packaging: 100% recycled and recyclable cardboard; soy-based inks; zero single-use plastic
# - End-of-life: Fully recyclable; manufacturer-operated take-back program available for B2B accounts
# - Estimated product lifespan: ≥ 10 years under standard use conditions
#
# ---
#
# **Dimensions & Compatibility**
#
# - Height: 27.5 cm (10.8 in)
# - Diameter (base): 7.3 cm (2.9 in)
# - Fits standard automotive cup holders (≤ 8.5 cm diameter)
# - Compatible with universal 63 mm wide-mouth accessories
#
# ---
#
# **Available Configurations**
#
# Offered in matte and gloss finish variants; custom corporate branding (laser engraving and co-branding) available for orders of 500 units or greater. Private-label procurement inquiries are accommodated upon execution of a non-disclosure agreement.
#
# ---
#
# *For technical data sheets, third-party test reports, or bulk procurement terms, contact our B2B sales division.*
#
#
#
#
# --------------------------------------------------------------------------------
# Approach 2: CONVERSATIONAL
# --------------------------------------------------------------------------------
#
#
# Meet your new favorite hydration companion 💧
#
# Say hello to the water bottle that's as good for the planet as it is for your daily routine. Whether you're rushing to a morning meeting, hitting the gym, or just trying to drink more water (we see you!), this bottle has got your back — and your thirst.
#
# **Why you're going to love it:**
#
# Made from 100% recycled materials, this bottle lets you sip with a clear conscience. No BPA, no nasties, no guilt. Just pure, fresh-tasting water all day long. The double-wall insulation keeps your cold drinks icy for up to 24 hours and your hot drinks warm for up to 12 — because lukewarm coffee is simply not an option.
#
# The leak-proof lid means you can toss it in your bag without a second thought (your laptop will thank you), and the sleek, lightweight design makes it easy to carry wherever life takes you.
#
# **The feel-good factor:**
#
# Every bottle sold helps fund clean water initiatives around the world. So while you're staying hydrated, you're also helping someone else do the same. Pretty cool, right?
#
# It's the small swap that makes a big difference — for you, for others, and for the planet we all share.
#
# **Available in 6 gorgeous colors.** Because saving the Earth should look good too. 🌍✨
#
# *Grab yours today and start sipping smarter.*
#
#
#
# --------------------------------------------------------------------------------
# Approach 3: STORYTELLING/MISSION-DRIVEN
# --------------------------------------------------------------------------------
#
#
#
# # Every Sip Tells a Story
#
# It started with a simple, uncomfortable truth: over a million plastic bottles are purchased every single minute around the world. Most of them will outlive us. Many will end up in oceans, in soil, in the bodies of wildlife — and eventually, in ours.
#
# We couldn't look away. So we built something better.
#
# ---
#
# ## Meet the Bottle That Fights Back
#
# The **EverFlow Eco Bottle** isn't just a container for your morning coffee or post-run hydration. It's a declaration. A daily act of defiance against a throwaway culture that has pushed our planet to its limits.
#
# Crafted from **100% certified recycled stainless steel**, insulated to keep your drinks cold for 24 hours and hot for 12, and sealed with a leak-proof cap made from plant-based bioplastic — EverFlow was designed to last a lifetime, because that's exactly how long it needs to.
#
# ---
#
# ## The Numbers That Matter
#
# We believe accountability is part of sustainability. So here's what choosing EverFlow actually means:
#
# - 🌊 **~156 single-use plastic bottles saved per person, per year**
# - 🌿 **Carbon footprint reduced by up to 73%** compared to buying bottled water annually
# - ♻️ **Every bottle produced diverts the equivalent of 8 plastic bottles** from landfill through our recycled materials program
# - 🌍 **1% of every purchase** goes directly to ocean cleanup initiatives through our partnership with global conservation nonprofits
#
# By the time you've carried EverFlow for one year, you haven't just made a purchase — you've made a measurable difference.
#
# ---
#
# ## You're Not Just a Customer. You're Part of the Movement.
#
# Behind every EverFlow bottle is a mission that stretches far beyond our factory walls. We partner with coastal communities to fund plastic recovery programs. We offset 100% of our manufacturing emissions. We publish an annual impact report because we believe you deserve to see exactly where your money goes.
#
# But here's the truth we hold closest: **we can't do this alone.**
#
# The most powerful thing we make isn't a water bottle. It's a community of people who refuse to accept that convenience is worth the cost of our planet. People who understand that the small, consistent choices — the ones made at a kitchen counter, a gym bag, a coffee shop — are the ones that quietly reshape the world.
#
# When you carry EverFlow, you carry that story with you. You become part of it.
#
# ---
#
# ## Built for the Planet. Built for Your Life.
#
# - ✅ BPA-free & toxin-free materials
# - ✅ Double-wall vacuum insulation
# - ✅ Fits standard car cup holders
# - ✅ Dishwasher safe
# - ✅ Available in 18oz, 24oz, and 32oz
# - ✅ Lifetime guarantee — because we mean it
#
# ---
#
# *The ocean doesn't need our guilt. It needs our action.*
#
# **Choose EverFlow. Drink with purpose.**

# %% [markdown]
# ## Summary
#
# You've now implemented an orchestrator-workers pattern that dynamically adapts its task breakdown based on the specific input. This pattern generated multiple marketing copy variations—each tailored to different audiences and contexts—without requiring you to pre-define what those variations should be.
#
# ### Key Takeaways
#
# **Pattern benefits:**
# - **Adaptability**: The orchestrator determines the best approach for each unique input
# - **Flexibility**: Easy to apply to different domains by changing the prompts
# - **Structured coordination**: XML-based communication ensures reliable parsing
# - **Error resilience**: Validation catches and handles worker failures
#
# **When this pattern excels:**
# - Content generation requiring multiple perspectives (marketing, documentation, creative writing)
# - Analysis tasks benefiting from different analytical lenses
# - Problem-solving where the decomposition strategy depends on the problem
#
# ### Limitations & Considerations
#
# **Cost & Latency:**
# - Requires N+1 LLM calls (1 orchestrator + N workers)
# - Sequential processing in this implementation (workers run one at a time)
# - For better performance, consider parallelizing worker calls with `asyncio` or thread pools
#
# **When NOT to use this pattern:**
# - Simple tasks with single, clear outputs (the added complexity isn't justified)
# - Latency-critical applications (multiple API calls add overhead)
# - Tasks where subtasks are always the same (use pre-defined parallelization instead)
#
# **Failure modes to consider:**
# - Orchestrator might not break down tasks optimally (prompt engineering is critical)
# - Workers may return empty or malformed responses (we handle this with validation)
# - XML parsing can fail if models don't follow format exactly (consider using JSON as an alternative)
#
# ### Next Steps
#
# **Enhance this implementation:**
# 1. Add parallel worker execution using `asyncio` for better performance
# 2. Implement retry logic for failed workers
# 3. Add a synthesis phase where an LLM combines worker outputs
# 4. Experiment with different orchestrator strategies (e.g., asking for more/fewer subtasks)
#
# **Adapt to your use case:**
# - Modify the orchestrator prompt to guide task decomposition for your domain
# - Adjust worker prompts to provide domain-specific instructions
# - Add context parameters relevant to your application
# - Consider using Claude Opus for the orchestrator and Claude Haiku for workers to optimize cost vs. quality
